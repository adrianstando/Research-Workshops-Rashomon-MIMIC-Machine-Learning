# %% [markdown]
# # RashomonSetAnalyser class ver. 1.0

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import dalex as dx
import copy

# %%
from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier
X, y = datasets.load_breast_cancer(return_X_y=True, as_frame=True)

params = {'n_estimators': list(np.arange(10, 50, 10, dtype = 'int'))}
rf = RandomForestClassifier()

# %%
from RashomonSetAnalyser import RashomonSetAnalyser

# %% [markdown]
# ### How this class works?

# %%
rashomon = RashomonSetAnalyser()

# %%
rashomon.base_model is None
# Out:
# True

# %%
rashomon.generate_rashomon_set(X, y, rf, searcher_type = 'grid', rashomon_ratio = 1, param_grid = params)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.034286      0.000377         0.004175        0.000181
# 1       0.018947      0.000756         0.003354        0.000258
# 2       0.065511      0.001687         0.006037        0.000300
# 3       0.049235      0.001204         0.005032        0.000063
#
#   param_n_estimators                params  split0_test_score  \
# 0                 20  {'n_estimators': 20}           0.938596
# 1                 10  {'n_estimators': 10}           0.929825
# 2                 40  {'n_estimators': 40}           0.929825
# 3                 30  {'n_estimators': 30}           0.912281
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.964912           0.991228           0.973684           0.973451
# 1           0.964912           0.982456           0.973684           0.973451
# 2           0.947368           0.991228           0.982456           0.955752
# 3           0.938596           0.982456           0.956140           0.973451
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.968374        0.017175                1
# 1         0.964866        0.018378                2
# 2         0.961326        0.022622                3
# 3         0.952585        0.025141                4

# %%
rashomon.base_model
# Out:
# ['Base model', RandomForestClassifier(n_estimators=20)]

# %%
rashomon.models
# Out:
# [['Model 1', RandomForestClassifier(n_estimators=10)],
#  ['Model 2', RandomForestClassifier(n_estimators=40)],
#  ['Model 3', RandomForestClassifier(n_estimators=30)]]

# %%
rashomon.change_rashomon_ratio(0.6)

# %%
rashomon.models
# Out:
# [['Model 1', RandomForestClassifier(n_estimators=10)],
#  ['Model 2', RandomForestClassifier(n_estimators=40)]]

# %% [markdown]
# ### Fit models

# %%
rashomon.fit(X, y)

# %% [markdown]
# ### Compare PDP

# %%
rashomon.pdp_comparator(X, y)
# Out:
#                     colname   Model 1   Model 2
# 0               mean radius  5.219500  3.393417
# 1              mean texture  1.203833  0.645417
# 2            mean perimeter  1.709833  1.009667
# 3                 mean area  3.206500  1.554667
# 4           mean smoothness  2.090333  0.695750
# 5          mean compactness  0.274667  1.802000
# 6            mean concavity  1.541833  1.974417
# 7       mean concave points  4.127833  0.828500
# 8             mean symmetry  0.206833  0.158500
# 9    mean fractal dimension  1.543667  0.074750
# 10             radius error  1.908667  1.504917
# 11            texture error  0.165000  0.408833
# 12          perimeter error  0.822167  3.256667
# 13               area error  0.567333  3.388250
# 14         smoothness error  1.076000  0.242333
# 15        compactness error  0.820333  0.580917
# 16          concavity error  1.412667  1.517167
# 17     concave points error  0.160167  0.351667
# 18           symmetry error  0.542667  0.467917
# 19  fractal dimension error  1.166667  0.697667
# 20             worst radius  2.438333  1.892750
# 21            worst texture  0.981667  1.684333
# 22          worst perimeter  2.449500  3.063167
# 23               worst area  3.153500  2.237417
# 24         worst smoothness  1.497000  1.239083
# 25        worst compactness  0.287500  1.027417
# 26          worst concavity  3.276333  5.630500
# 27     worst concave points  1.491000  1.597000
# 28           worst symmetry  3.802667  0.528917
# 29  worst fractal dimension  0.456333  0.458333

# %%
rashomon.pdp_comparator(X, y, metric = 'integrate')
# Out:
#                     colname      Model 1      Model 2
# 0               mean radius   -97.057100   -70.492257
# 1              mean texture    29.969772   -11.772549
# 2            mean perimeter  -210.114552     7.123237
# 3                 mean area -4686.481596  1991.587044
# 4           mean smoothness    -0.032994     0.007596
# 5          mean compactness     0.040858     0.441499
# 6            mean concavity    -0.409636     0.414223
# 7       mean concave points    -0.401068     0.082000
# 8             mean symmetry     0.033852     0.002858
# 9    mean fractal dimension    -0.111425     0.001364
# 10             radius error     2.994118    -2.115306
# 11            texture error    -0.078878    -1.284240
# 12          perimeter error    -9.099753    42.597454
# 13               area error    68.126473 -1035.653558
# 14         smoothness error    -0.017030     0.003866
# 15        compactness error     0.083267     0.019381
# 16          concavity error     0.330717     0.374846
# 17     concave points error    -0.003338    -0.012526
# 18           symmetry error    -0.022674     0.011560
# 19  fractal dimension error     0.024166    -0.011327
# 20             worst radius    48.383553   -22.078056
# 21            worst texture   -11.318512    53.440411
# 22          worst perimeter   387.755086   390.512150
# 23               worst area -7120.251331 -5317.726308
# 24         worst smoothness     0.193644     0.203435
# 25        worst compactness    -0.148248     0.636822
# 26          worst concavity    -2.490518    -3.653754
# 27     worst concave points     0.089956     0.220302
# 28           worst symmetry     1.894210     0.155257
# 29  worst fractal dimension    -0.028700    -0.045607

# %% [markdown]
# ### Comapre PDP with parameter *save_model_profiles=True* and change metrics

# %%
rashomon.pdp_comparator(X, y, save_model_profiles = True)
# Out:
#                     colname   Model 1   Model 2
# 0               mean radius  5.219500  3.393417
# 1              mean texture  1.203833  0.645417
# 2            mean perimeter  1.709833  1.009667
# 3                 mean area  3.206500  1.554667
# 4           mean smoothness  2.090333  0.695750
# 5          mean compactness  0.274667  1.802000
# 6            mean concavity  1.541833  1.974417
# 7       mean concave points  4.127833  0.828500
# 8             mean symmetry  0.206833  0.158500
# 9    mean fractal dimension  1.543667  0.074750
# 10             radius error  1.908667  1.504917
# 11            texture error  0.165000  0.408833
# 12          perimeter error  0.822167  3.256667
# 13               area error  0.567333  3.388250
# 14         smoothness error  1.076000  0.242333
# 15        compactness error  0.820333  0.580917
# 16          concavity error  1.412667  1.517167
# 17     concave points error  0.160167  0.351667
# 18           symmetry error  0.542667  0.467917
# 19  fractal dimension error  1.166667  0.697667
# 20             worst radius  2.438333  1.892750
# 21            worst texture  0.981667  1.684333
# 22          worst perimeter  2.449500  3.063167
# 23               worst area  3.153500  2.237417
# 24         worst smoothness  1.497000  1.239083
# 25        worst compactness  0.287500  1.027417
# 26          worst concavity  3.276333  5.630500
# 27     worst concave points  1.491000  1.597000
# 28           worst symmetry  3.802667  0.528917
# 29  worst fractal dimension  0.456333  0.458333

# %%
rashomon.pdp_comparator_change_metric(metric = 'integrate')
# Out:
#                     colname      Model 1      Model 2
# 0               mean radius   -97.057100   -70.492257
# 1              mean texture    29.969772   -11.772549
# 2            mean perimeter  -210.114552     7.123237
# 3                 mean area -4686.481596  1991.587044
# 4           mean smoothness    -0.032994     0.007596
# 5          mean compactness     0.040858     0.441499
# 6            mean concavity    -0.409636     0.414223
# 7       mean concave points    -0.401068     0.082000
# 8             mean symmetry     0.033852     0.002858
# 9    mean fractal dimension    -0.111425     0.001364
# 10             radius error     2.994118    -2.115306
# 11            texture error    -0.078878    -1.284240
# 12          perimeter error    -9.099753    42.597454
# 13               area error    68.126473 -1035.653558
# 14         smoothness error    -0.017030     0.003866
# 15        compactness error     0.083267     0.019381
# 16          concavity error     0.330717     0.374846
# 17     concave points error    -0.003338    -0.012526
# 18           symmetry error    -0.022674     0.011560
# 19  fractal dimension error     0.024166    -0.011327
# 20             worst radius    48.383553   -22.078056
# 21            worst texture   -11.318512    53.440411
# 22          worst perimeter   387.755086   390.512150
# 23               worst area -7120.251331 -5317.726308
# 24         worst smoothness     0.193644     0.203435
# 25        worst compactness    -0.148248     0.636822
# 26          worst concavity    -2.490518    -3.653754
# 27     worst concave points     0.089956     0.220302
# 28           worst symmetry     1.894210     0.155257
# 29  worst fractal dimension    -0.028700    -0.045607

# %%
rashomon.pdp_comparator_change_metric(metric = 'sum')
# Out:
#                     colname   Model 1   Model 2
# 0               mean radius -5.219500 -3.322750
# 1              mean texture  0.966500 -0.302417
# 2            mean perimeter -1.570500  0.368833
# 3                 mean area -3.056833  1.554667
# 4           mean smoothness -0.988333 -0.172250
# 5          mean compactness  0.162667  1.741833
# 6            mean concavity -1.441833  1.183917
# 7       mean concave points -4.127833  0.699500
# 8             mean symmetry  0.199500  0.055667
# 9    mean fractal dimension -1.249000  0.023583
# 10             radius error  1.569333 -1.107583
# 11            texture error  0.048333 -0.406000
# 12          perimeter error -0.641833  3.101833
# 13               area error  0.527333 -3.367583
# 14         smoothness error -0.696667  0.167000
# 15        compactness error  0.779000  0.066583
# 16          concavity error  1.096667  1.342667
# 17     concave points error -0.129500 -0.322000
# 18           symmetry error -0.501000  0.152083
# 19  fractal dimension error  1.103333 -0.639667
# 20             worst radius  2.217667 -0.444250
# 21            worst texture -0.049000  1.534833
# 22          worst perimeter  2.318833  1.768667
# 23               worst area -2.448167 -2.185083
# 24         worst smoothness  1.210333  1.220250
# 25        worst compactness -0.240500  0.609750
# 26          worst concavity -2.656667 -3.767500
# 27     worst concave points  0.846667  1.413167
# 28           worst symmetry  3.649667  0.465083
# 29  worst fractal dimension -0.206333 -0.374667

# %% [markdown]
# ### Choose a subset of variables

# %%
rashomon.pdp_comparator(X, y, save_model_profiles = True, variables = ['mean area', 'worst area'])
# Out:
#       colname  Model 1   Model 2
# 0   mean area   3.2065  1.554667
# 1  worst area   3.1535  2.237417

# %%
rashomon.pdp_comparator_change_metric(metric = 'integrate')
# Out:
#       colname      Model 1      Model 2
# 0   mean area -4686.481596  1991.587044
# 1  worst area -7120.251331 -5317.726308

# %%
rashomon.pdp_comparator_change_metric(metric = 'sum')
# Out:
#       colname   Model 1   Model 2
# 0   mean area -3.056833  1.554667
# 1  worst area -2.448167 -2.185083
